# %% [markdown]
# #***Assignment-4***
# #**Theory Questions:-**

# %% [markdown]
# **1) What is Object-Oriented Programming (OOP)?**
#
# **Ans:-**Object-oriented programming (OOP) is a style of programming characterized by the identification of classes of objects closely linked with the methods (functions) with which they are associated. It also includes ideas of inheritance of attributes and methods.OOP allows objects to interact with each other using four basic principles: encapsulation, inheritance, polymorphism, and abstraction. These four OOP principles enable objects to communicate and collaborate to create powerful applications.
#
# For example, “+” can be used for addition as well as string concatenation. Static Polymorphism is based on Method Overloading, and Dynamic Polymorphism is based on Method Overriding.
#
# **2)What is a class in OOP?**
#
# **Ans:-**A class is a user-defined data type that serves as a blueprint for creating objects.Classes are used to create and manage new objects, and to support inheritance, a key concept in OOP.
#
# For example ,A class could represent a person, with a private data member like a social security number, and a method like bankTransaction() that might access the social security number.
#
# **3) What is an object in OOP?**
#
# **Ans:-** An object is a unit of code that represents a data structure or abstract data type. Objects are the basic building blocks of OOP applications and are the things that are considered first when designing a program.Objects contain fields, or state variables, that hold data, and methods, or procedures, that define the object's behavior. Objects are instances of a class or subclass, which defines their structure.Objects can interact with each other through defined interfaces. Objects can sometimes correspond to real-world things, such as a person, a car, a shopping cart, or a customer. Objects can also represent more abstract entities, such as an open file or a measurement translator.
#
# **4) What is the difference between abstraction and encapsulation?**
#
# **Ans:-** Abstraction and encapsulation are both used to simplify complex systems, but they differ in their focus and goals:
#
# **Abstraction:-**
#
# Abstraction focuses on what an object does, and hides unnecessary details to make it easier to understand. Abstraction can help programmers create reusable components that can be adapted to different situations.Abstraction is implemented using abstract classes and interfaces.
#
# for example, A car's steering wheel and pedals abstract the complex driving mechanisms.
#
# **Encapsulation:-**
#
# Encapsulation focuses on how an object's data is accessed and manipulated, and hides the internal details of how an object works. Encapsulation can help ensure data integrity and privacy by preventing unauthorized access and modification.Encapsulation is implemented using access modifiers like private, protected, and public.
#
# for example, the car engine's internal components are encapsulated.
#
# **5) What are dunder methods in Python?**
#
# **Ans:-** Dunder methods known as magic methods or special methods,its predefined methods that are used to give special functionality to classes and objects. The term "dunder" is short for "double underscores". Dunder methods are recognized by the double underscore format: __methodname__()
# Dunder methods are used to Perform arithmetic operations on numeric type attributes ,Initialize a new class instance, Overload certain methods to make their behaviors unique to that class, Create objects from a class
# Provide a string representation of an object , Make a class iterable, Compare objects.
#
# for example,
#
# **init():** Initializes the state of a new instance
#
# **add():** Defines an element-wise addition operation using the + operator
#
# **aiter():** Returns an asynchronous iterator
#
# **anext():** Returns an awaitable object
#
# **6) Explain the concept of inheritance in OOP.**
#
# **Ans:-** Inheritance is a fundamental concept in object-oriented programming (OOP) that allows a class to inherit properties and behaviors from another class. This creates a hierarchy of classes that share attributes and methods.The class whose members are inherited. It's also known as the superclass or parent class.The class that inherits the members of the base class. It's also known as the subclass or child class. Inheritance allows you to reuse code by inheriting attributes and methods from an existing class. This reduces redundancy and makes code more efficient.Inheritance creates a hierarchical relationship between classes, which provides a structured approach to building and extending classes.
#
# for example:-
#
#     # Parent class
#     class Animal:
#     def __init__(self, name):
#         self.name = name
#
#     def speak(self):
#         pass
#
#     # Child class inheriting from Animal
#         class Dog(Animal):
#     def speak(self):
#         return f"{self.name} barks!"  # Override the speak method
#
#     # Creating an instance of Dog
#       dog = Dog("Buddy")
#         print(dog.speak())
#
#
#  Output: Buddy says Woof!
#
#
#  **7) What is polymorphism in OOP?**
#
#  **Ans:-** Polymorphism is a core concept in object-oriented programming (OOP) that allows objects of different types to be treated as objects of a common superclass. It's a feature that allows a programming language to present the same interface for different underlying data types.
#
#  **increases code reusability:** Multiple classes can implement the same method in different ways.
#
# **Allows for abstraction and encapsulation:** Polymorphism is essential for achieving these concepts in programming languages.
#
# **Makes code cleaner and more intuitive:** A program can handle different tasks with the same method name.
#
# For example:-1] Built-in function
#
#     print(len("Hello"))  # String length
#     print(len([1, 2, 3]))  # List length
#
#     print(max(1, 3, 2))  # Maximum of integers
#     print(max("a", "z", "m"))  # Maximum in strings
#
#
#
#
#   2]polymorphism in functions
#
#     def add(a, b):
#     return a + b
#     print(add(3, 4))           # Integer addition
#     print(add("Hello, ", "World!"))  # String concatenation
#     print(add([1, 2], [3, 4])) # List concatenation
#
#
# **8) How is encapsulation achieved in Python?**
#
# **Ans:-** encapsulation is achieved by using access modifiers to limit access to a class's variables and methods. Python uses a convention-based approach, rather than keywords like "public", "private", and "protected":
#
# **Private members**
# Use a double underscore prefix (__) to indicate a private member. Private members are only accessible within the class and are intended for internal use.
#
# **Protected members**
# Use a single underscore prefix (_) to indicate a protected member. Protected members are intended to be used within the class and its subclasses.
#
# **Public members**
# By default, all attributes and methods in a Python class are public and can be accessed from outside the class.
#
# for example,
#
#     def __init__(self, account_number):
#       self.__account_number = account_number # Private attribute
#     def __validate_pin(self, pin): # Private method to validate the PIN
#        return len(str(pin)) == 4
#
# In this example, the __account_number attribute and the __validate_pin method are marked as private using double underscores
#
#
#
# **9)What is a constructor in Python?**
#
# **Ans:-** A constructor is a special method that's automatically called when an object is created from a class.The main purpose of a constructor is to initialize the attributes of an object when it's created. The constructor method's name is always __init__ .The __init__ method is called with the newly created object as the first argument. The method can then use the self keyword to initialize the object's attributes.
#
# For Example,
# In the example below, the __init__ method is called when the Person object is created, and it sets the name and age attributes of the object:
#
#      class Person:
#       def __init__(self, name, age):
#           self.name = lisha
#           self.age = 22
#
#
#
#   **10)What are class and static methods in Python?**
#
#   **Ans:-** class methods and static methods are different types of methods that are attached to a class, but have different characteristics and uses:-
#
#   **Class methods**
# These methods are attached to the class itself, not the class's object. They can access and modify the class state, and are often used for actions related to the class. Class methods can also be used as alternative constructors. The first parameter of a class method is cls. To create a class method, use the
#  classmethod decorator.
#
#     from datetime import date
#     class Person:
#      def __init__(self, name, age):
#     self.name = name
#     self.age = age
#     @classmethod
#      def fromBirthYear(cls, name, birthYear):
#     return cls(name, date.today().year - birthYear)
#
# **Static methods**
# These methods are also attached to the class, but they cannot access or modify the class state. Static methods are used for utility functions that don't require access to the class or instance. To create a static method, use the
#  staticmethod decorator.
#
#     class myClass:
#     def __init__(self):
#     self.x = x
#      @staticmethod
#     def staticMethod():
#     return "i am a static method"
#
#
# **11) What is method overloading in Python?**
#
# **Ans:-** Method overloading is a function that allows you to call the same method in different ways by passing different arguments. You can create a method with a variable number of parameters, and then call it with different numbers of arguments.
# For example, you can create a method that can be called with zero, one, or more arguments.
# Method overloading can make your code more flexible, intuitive, and cleaner. It can also improve the quality of your code and make it more reusable and accessible.
#
# for example:-
#
#
#     def product(a, b):
#     p = a * b
#     print(p)
#
#     # Second product method
#      def product(a, b, c):
#     p = a * b*c
#     print(p)
#     # product(4, 5)
#      # This line will call the second product method
#       product(4, 5, 5)
#
#
#   Output:- 100
#
#
# **12) What is method overriding in OOP?**
#
# **Ans:-** Method overriding is a feature in object-oriented programming (OOP) that allows a subclass to replace a method in its superclass with its own implementation.
# The subclass method has the same name, parameters, and return type as the superclass method. The version of the method that is executed depends on the object used to invoke itMethod overriding allows developers to customize the behavior of inherited methods without changing the parent class's code. It also enables polymorphism, which allows objects of different classes to be treated interchangeably.
#
# for example:-
#
#
#       class Parent():
#      # Constructor
#     def __init__(self):
#         self.value = "Inside Parent"
#
#     # Parent's show method
#     def show(self):
#         print(self.value)
#
#     # Defining child class
#         class Child(Parent):
#
#     # Constructor
#     def __init__(self):
#         super().__init__()  # Call parent constructor
#         self.value = "Inside Child"
#
#     # Child's show method
#     def show(self):
#         print(self.value)
#
#     # Driver's code
#     obj1 = Parent()
#     obj2 = Child()
#
#     obj1.show()
#     obj2.show()
#
#   Output:-
#
# Inside Parent
#
# Inside Child
#
#
#
# **13) What is a property decorator in Python?**
#
# **Ans:-** The decorator is a built-in function that allows you to turn class methods into properties in a way that's both elegant and user-friendly.Decorators are typically applied to functions, and they play a crucial role in enhancing or modifying the behavior of functions.
#
# for example:_
#
#     # Python program to illustrate the use of
#     # @property decorator
#
#     # Defining class
#     class Portal:
#
#     # Defining __init__ method
#     def __init__(self):
#         self.__name =''
#
#     # Using @property decorator
#     @property
#
#     # Getter method
#     def name(self):
#         return self.__name
#
#     # Setter method
#     @name.setter
#     def name(self, val):
#         self.__name = val
#
#     # Deleter method
#     @name.deleter
#     def name(self):
#        del self.__name
#
#     # Creating object
#       p = Portal();
#
#     # Setting name
#     p.name = 'abcdefg'
#
#     # Prints name
#     print (p.name)
#
#     # Deletes name
#      del p.name
#
#     # As name is deleted above this
#     # will throw an error
#     print (p.name)
#
#   Output:-
#
# abcdefg
#
#
# Traceback (most recent call last):
#
# File "main.py", line 42, in
#
#   print (p.name)
#
#   File "main.py", line 16, in name
#
#   return self.__name
#
#  AttributeError: 'Portal' object has no attribute '_Portal__name'
#
#
#  **14) Why is polymorphism important in OOP?**
#
#  **Ans:-** Polymorphism is a key feature of object-oriented programming (OOP) that allows programmers to write more efficient, readable, and maintainable code. Here are some of the benefits of polymorphism.
#  Polymorphism allows programmers to **reuse code**, which saves time and speeds up development.
#
# **Improved readability:** Polymorphism can improve code readability by allowing functions to share the same name but have different arguments.
#
# **Better error handling:** Polymorphism can improve error handling in code.
#
# **Simplified debugging:** Polymorphism can simplify code debugging.
#
# **Extensibility:** Polymorphism allows developers to easily create new classes derived from existing classes.
#
# **Reduced redundancy:** Polymorphism can help reduce redundancy in code by removing the need to write similar code repeatedly.
#
# **Plugin architecture:** Polymorphism allows the called module to act like a plugin, which can make programs more robust.
# Polymorphism can also be used in quantum computing to develop flexible frameworks and libraries that support different hardware platforms.
#
#
# **15)What is an abstract class in Python?**
#
# **Ans:-** an abstract class is a class that cannot be instantiated on its own and is designed to be a blueprint for other classes:
# Purpose.Abstract classes define methods that must be implemented by subclasses, ensuring a consistent interface while still allowing the subclasses to provide specific implementations. Abstract classes enforce a common structure and behavior, and prevent instantiation of the class itself.
#
# For example:-
#
#      from abc import ABC, abstractmethod
#
#     # Define an abstract class
#     class Animal(ABC):
#
#     @abstractmethod
#     def sound(self):
#         pass  # This is an abstract method, no implementation here.
#
#     # Concrete subclass of Animal
#     class Dog(Animal):
#
#     def sound(self):
#         return "Bark"  # Providing the implementation of the abstract method
#
#      # Create an instance of Dog
#           dog = Dog()
#          print(dog.sound())
#
#
#   Output:-
#
#    Bark
#
#
# **16)What are the advantages of OOP?**
#
# **Ans:-** Object-oriented programming (OOP) has many advantages, including:-
#
# **Modularity**
# Objects are self-contained, making it easier to troubleshoot and collaborate.
#
# **Reusability**
# Code can be reused through inheritance, so teams don't have to write the same code multiple times.
#
# **Security**
# Encapsulation and abstraction hide complex code, making software maintenance easier and protecting internet protocols.
#
# **Flexibility**
# Polymorphism allows a single function to adapt to the class it is placed in.
#
# **Productivity**
# Programmers can quickly construct new programs using reusable code and multiple libraries.
#
# **Collaboration**
# Developers can divide a complex software system into small, manageable objects, each responsible for a specific function.
#
# **Troubleshooting**
# It's simpler to troubleshoot because the user knows where to look in the code to find the source of the problem.
#
# **Abstraction**
# Classes are defined by their essential characteristics and behaviors, making it easier to manage and understand complex systems.
#
# **Problem-solving**
# OOP is used for solving big problems.
#
#
# **17) What is the difference between a class variable and an instance variable?**
#
# **Ans:-**  Using class- and instance-specific variables can help reduce repetition in code.The main difference between a class variable and an instance variable is that a class variable is shared across all instances of a class, while an instance variable is unique to each instance of a class:
#
# **Class variable**
# A class variable is a variable defined in a class that exists as a single copy, regardless of how many instances of the class are created. Class variables are shared between a class and all of its subclasses.Class variables can be used to initialize objects with a specific value.It usually maintains a single shared value for all instances of class even if no instance object of the class exists.  It is generally created when the program begins to execute.  It normally retains values until the program terminates.It has only one copy of the class variable so it is shared among different objects of the class.These variables are declared using the keyword static. Changes that are made to these variables through one object will reflect in another object.
#
# for example:-
#
#
#     class Taxes
#     {
#     static int count;
#     /*...*/
#     }
#
# **Instance variable**
# An instance variable is a variable defined in a class that has a separate copy for each instance of the class. Instance variables are unique to each instance of a class. instance variables can be used to assign different variables to each object.It is generally created when an instance of the class is created. It usually reserves memory for data that the class needs. It normally retains values as long as the object exists. It has many copies so every object has its own personal copy of the instance variable. These variables are declared without using the static keyword.Changes that are made to these variables through one object will not reflect in another object.
#
# for example:-
#
#
#     class Taxes
#     {
#     int count;
#     /*...*/
#     }
#
#
#
# **18) What is multiple inheritance in Python?**
#
# **Ans:-** Multiple inheritance is a feature in Python that allows a class to inherit attributes and methods from more than one parent class:
# Here are some benefits of multiple inheritance:
#
# **Complex class hierarchies:** Multiple inheritance allows for the creation of complex class hierarchies.
#
# **Code reuse:** Multiple inheritance promotes code reuse by combining functionalities from different base classes into a single derived class.
#
# **Modular code:** Multiple inheritance results in more flexible and modular code.
#
#  For example, you can independently update or extend each parent class.
#
# Syntax:
#
#     Class Base1:
#        Body of the class
#
#     Class Base2:
#      Body of the class
#
#     Class Derived(Base1, Base2):
#      Body of the class
#
#
#
# **19) Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python.**
#
# **Ans:-** the __str__ and __repr__ methods are used to return string representations of an object:
#
# 1] __str__
# Returns a readable, informal string representation of an object. This method is used for logging or displaying object information for end-users. The print(), str(), and format() functions use the __str__ method internally.
#
# for example:-
#
#     s = 'Hello, world.'
#     print (str(s))
#     print (str(2.0/11.0))
#
# Output:-
#
# Hello, world.
# 0.181818181818
#
#
# 2] __repr__
# Returns a detailed, unambiguous string representation of an object. This method is used for debugging and development purposes. The repr() function uses the __repr__ method internally.
#
# for example:-
#
#     s = 'Hello, world.'
#     print (repr(s))
#     print (repr(2.0/11.0))
#
#
# Output:-
# 'Hello, world.'
# 0.18181818181818182
#
#
# **20)What is the significance of the ‘super()’ function in Python?**
#
# **Ans:-** The super() function  is a built-in function that allows access to a parent or superclass's methods and properties from a child or subclass. This function is useful for object-oriented programming when working with inheritance.
# Here are some of the benefits of using the super() function:
#
# **Inheritance:** Allows a subclass to inherit attributes and behavior from its parent class.
#
# **Flexibility:** Allows the subclass to override or extend the behavior of the parent class.
#
# **Code maintenance:** Makes code easier to maintain by allowing you to call a method from the parent class without explicitly naming the parent class.
#
# **Recoding:** Saves you from rebuilding and recoding methods in your subclass.
#
# **Swapping out superclasses:** Allows you to swap out superclasses with minimal code modifications.
#
# **Different base classes:** Since it is computed at runtime, you can use different base classes at different times.
#
# for example:-
#
#     lass Emp():
#     def __init__(self, id, name, Add):
#         self.id = id
#         self.name = name
#         self.Add = Add
#
#     # Class freelancer inherits EMP
#     class Freelance(Emp):
#     def __init__(self, id, name, Add, Emails):
#         super().__init__(id, name, Add)
#         self.Emails = Emails
#
#     Emp_1 = Freelance(103, "lisha s maind", "Noida" , ",maindlisha@gmail.com")
#     print('The ID is:', Emp_1.id)
#     print('The Name is:', Emp_1.name)
#     print('The Address is:', Emp_1.Add)
#     print('The Emails is:', Emp_1.Emails)
#
#
# Output:-
#
# The ID is: 103
#
# The Name is: lisha s maind
#
# The Address is: Noida
#
# The Emails is: maindlisha@gmail.com
#
#
#
# **21)What is the significance of the __del__ method in Python?**
#
# **Ans:-** _del__ is a finalizer. It is called when an object is garbage collected which happens at some point after all references to the object have been deleted. In a simple case this could be right after you say del x or, if x is a local variable, after the function ends.
#
# for example:-
#
#
#     class Example:
#
#     # Initializing
#     def __init__(self):
#         print("Example Instance.")
#
#     # Calling destructor
#     def __del__(self):
#         print("Destructor called, Example deleted.")
#
#     obj = Example()
#     del obj
#
#
# Output:-
#
# Example Instance.
# Destructor called, Example deleted.
#
#
# **22) What is the difference between @staticmethod and @classmethod in Python?**
#
# **Ans:-**
# class methods and static methods are different types of methods that are attached to a class, but have different characteristics and uses:-
#
#   **Class methods**
# These methods are attached to the class itself, not the class's object. They can access and modify the class state, and are often used for actions related to the class. Class methods can also be used as alternative constructors. The first parameter of a class method is cls. To create a class method, use the
#  classmethod decorator. Class methods require cls as a parameter
#
#     from datetime import date
#     class Person:
#      def __init__(self, name, age):
#     self.name = name
#     self.age = age
#     @classmethod
#      def fromBirthYear(cls, name, birthYear):
#     return cls(name, date.today().year - birthYear)
#
# **Static methods**
# These methods are also attached to the class, but they cannot access or modify the class state. Static methods are used for utility functions that don't require access to the class or instance. To create a static method, use the
#  staticmethod decorator. Static methods don't require any specific parameters.
#
#     class myClass:
#     def __init__(self):
#     self.x = x
#      @staticmethod
#     def staticMethod():
#     return "i am a static method"
#
#
#
#
# **23) How does polymorphism work in Python with inheritance?**
#
# **Ans:-** Polymorphism and inheritance in Python work together when a child class inherits methods and attributes from a parent class, and then redefines some of those methods to fit the child class. This process is called method overriding.
# polymorphism is useful when the method inherited from the parent class doesn't fit the child class.
# However, there are some things to keep in mind when using polymorphism in Python:
#
# **Overuse of inheritance**
# Avoid creating complex inheritance hierarchies that are difficult to understand and maintain.
#
# **Method overriding**
# Be careful which methods to override in subclasses. Overriding too many methods can make the code complex and error-prone.
#
# **Design considerations**
# Make sure that inheritance accurately reflects the "is-a" relationship.
#
# **Dynamic behavior**
# Be cautious when using polymorphism in Python because method resolution happens at runtime.
#
# for example:-
#
#      class Animal:
#     def sound(self):
#         return "Some generic animal sound"
#
#      class Dog(Animal):
#     def sound(self):
#         return "Bark"
#
#     class Cat(Animal):
#     def sound(self):
#         return "Meow"
#
#
#
# **24) What is method chaining in Python OOP?**
#
# **Ans:-** Method chaining in Python is a technique that allows multiple method calls to be chained together in a single line of code, on the same object. This is done by returning the object itself or a derived version of it from each method. This allows the next method to operate on the same object without the need to store intermediate results in variables.
# Method chaining can be used to perform a sequence of operations on an object, such as manipulating data, configuring settings, or querying databases. It can make code more concise, readable, and elegant.
#
# Syntax:-
#
#     result = obj.method1().method2().method3()
#
#
#
#
# **25) What is the purpose of the __call__ method in Python?**
#
# **Ans:-** _call__() is to turn your instances into callable objects. In other words, its purpose is to create objects that you can call as you would call a regular function. Most Python classes don't implement this method. Your custom classes will have it only if you need to use your instances as functions.
#
# for example:-
#
#     class Example:
#     def __init__(self):
#         print("Instance Created")
#
#     # Defining __call__ method
#     def __call__(self):
#         print("Instance is called via special method")
#
#     # Instance created
#     e = Example()
#
#     # __call__ method will be called
#     e()
#
# Output:-
#
# Instance Created
#
# Instance is called via special method

# %% [markdown]
# # ***PRACTICAL QUESTIONS:-***

# %%
#1) Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog that overrides the speak() method to print "Bark!"

# %%
class Animal:  # Parent class
    def speak(self):
        print("An animal makes a sound")

class Dog(Animal):  # Child class inheriting from Animal
    def speak(self):
        print("Bark!")  # Overriding the speak method
        animal = Animal()
animal.speak()

dog = Dog()
dog.speak()
# Out:
# An animal makes a sound
# Bark!

# %%
# 2) Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle from it and implement the area() method in both.
from abc import ABC, abstractmethod  # Importing necessary modules

class Shape(ABC):  # Defining the abstract class
    @abstractmethod
    def area(self):
        pass  # Abstract method, no implementation here

class Circle(Shape):  # Concrete subclass of Shape
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14159 * self.radius * self.radius  # Implementing area for Circle

class Rectangle(Shape):  # Concrete subclass of Shape
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width  # Implementing area for Rectangle
        circle = Circle(radius=5)
print(f"Area of the circle: {circle.area()}")

rectangle = Rectangle(length=10, width=5)
print(f"Area of the rectangle: {rectangle.area()}")
# Out:
# Area of the circle: 78.53975
# Area of the rectangle: 50

# %%
# 3)Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car and further derive a class ElectricCar that adds a battery attribute
class Vehicle:  # Base class
    def __init__(self, type):
        self.type = type

class Car(Vehicle):  # Inherits from Vehicle
    def __init__(self, type, model):
        super().__init__(type)  # Calling Vehicle's constructor
        self.model = model

class ElectricCar(Car):  # Inherits from Car
    def __init__(self, type, model, battery):
        super().__init__(type, model)  # Calling Car's constructor
        self.battery = battery

MEC = ElectricCar(type="car", model="Tesla Model S", battery="100kWh")

print(f"Vehicle Type: {MEC.type}")
print(f"Car Model: {MEC.model}")
print(f"Battery Capacity: {MEC.battery}")
# Out:
# Vehicle Type: car
# Car Model: Tesla Model S
# Battery Capacity: 100kWh

# %%
# 4)Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car and further derive a class ElectricCar that adds a battery attribute\
class Vehicle:  # Base class
    def __init__(self, type):
        self.type = type

class Car(Vehicle):  # Inherits from Vehicle
    def __init__(self, type, model):
        super().__init__(type)  # Calling Vehicle's constructor
        self.model = model

class ElectricCar(Car):  # Inherits from Car
    def __init__(self, type, model, battery):
        super().__init__(type, model)  # Calling Car's constructor
        self.battery = battery

MEC = ElectricCar(type="car SUV", model="TATA HARRIER", battery="200kWh")

print(f"Vehicle Type: {MEC.type}")
print(f"Car Model: {MEC.model}")
print(f"Battery Capacity: {MEC.battery}")
# Out:
# Vehicle Type: car SUV
# Car Model: TATA HARRIER
# Battery Capacity: 200kWh

# %%
# 5)  Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes balance and methods to deposit, withdraw, and check balance.
from typing import AsyncContextManager
class BankAccount:
    def __init__(self, initial_balance=0):
        self.__balance = initial_balance  # Private attribute

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited: ${amount:.2f}. New balance: ${self.__balance:.2f}")
        else:
            print("Invalid deposit amount.")

    def withdraw(self, amount):
        if 0 < amount <= self.__balance:
            self.__balance -= amount
            print(f"Withdrew: ${amount:.2f}. New balance: ${self.__balance:.2f}")
        else:
            print("Insufficient funds or invalid withdrawal amount.")

    def check_balance(self):
        print(f"Current balance: ${self.__balance:.2f}")
#The line below was unindented, causing the error. It should be at the same level as the other lines outside the class definition.
ACC = BankAccount(100000)  # Create an account with an initial balance of $100000

ACC.deposit(500)
ACC.withdraw(200)
ACC.check_balance()
# Out:
# Deposited: $500.00. New balance: $100500.00
# Withdrew: $200.00. New balance: $100300.00
# Current balance: $100300.00

# %%
# 6) Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar and Piano that implement their own version of play().
class Instrument:
    def play(self):
        print("Playing a generic instrument sound")

class Guitar(Instrument):
    def play(self):
        print("Strumming the guitar")

class Piano(Instrument):
    def play(self):
        print("Playing piano keys")

# Create instances of the classes
instrument = Instrument()
guitar = Guitar()
piano = Piano()

# Demonstrate runtime polymorphism
for obj in [instrument, guitar, piano]:
    obj.play()  # The correct play() method is called based on the object's type
# Out:
# Playing a generic instrument sound
# Strumming the guitar
# Playing piano keys

# %%
#7) Create a class MathOperations with a class method add_numbers() to add two numbers and a static method subtract_numbers() to subtract two numbers.
class MathOperations:

    @classmethod
    def add_numbers(cls, num1, num2):
        """Adds two numbers."""
        return num1 + num2

    @staticmethod
    def subtract_numbers(num1, num2):
        """Subtracts two numbers."""
        return num1 - num2

result_add = MathOperations.add_numbers(5, 3)  # Using class method
result_subtract = MathOperations.subtract_numbers(10, 4)  # Using static method

print(f"Addition result: {result_add}")
print(f"Subtraction result: {result_subtract}")
# Out:
# Addition result: 8
# Subtraction result: 6

# %%
#8) Implement a class Person with a class method to count the total number of persons created.
class Person:
    count = 0  # Class variable to count the number of persons

    def __init__(self, name, age=None):  # Provide a default value for age
        self.name = name
        self.age = age
        Person.count += 1  # Increment the count when a new person is created

    @classmethod
    def get_total_persons(cls):
        return cls.count

# Create some Person objects, providing age or using the default
person1 = Person("LISHA", 22)
person2 = Person("MEET", 26)
person3 = Person("VARAD")  # Using default age (None)

# Get the total count
total_persons = Person.get_total_persons()

print(f"Total persons created: {total_persons}")
# Out:
# Total persons created: 3

# %%
# 9) Write a class Fraction with attributes numerator and denominator. Override the str method to display the fraction as "numerator/denominator".

class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

# Creating an instance of the Fraction class
fraction = Fraction(5, 3)
print(f"Fraction 1: {fraction}")  # Using the __str__ method to display the fraction
# Out:
# Fraction 1: 5/3

# %%
#10)  Demonstrate operator overloading by creating a class Vector and overriding the add method to add two vectors.
class Vector:

    def __init__(self, x, y):

        self.x = x
        self.y = y

    def __add__(self, other):

        return Vector(self.x + other.x, self.y + other.y)

    def __str__(self):

        return f"({self.x}, {self.y})"

# Create two vector objects
v1 = Vector(2, 3)
v2 = Vector(4, 5)

# Add the two vectors using the overloaded + operator
v3 = v1 + v2

# Print the result
print(f"v1 + v2 = {v3}")
# Out:
# v1 + v2 = (6, 8)

# %%
#11) Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is {name} and I am {age} years old."
class Person:

    def __init__(self, name, age):

        self.name = name
        self.age = age

    def greet(self):

        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

# Create an instance of the Person class
person = Person("LISHA", 22)


person.greet()
# Out:
# Hello, my name is LISHA and I am 22 years old.

# %%
#12)  Implement a class Student with attributes name and grades. Create a method average_grade() to compute the average of the grades.
class Student:

    def __init__(self, name, grades):

        self.name = name
        self.grades = grades

    def average_grade(self):

        if not self.grades:  # Check if the grades list is empty
            return 0
        return sum(self.grades) / len(self.grades)

# Create an instance of the Student class
student = Student("LISHA", [95, 90, 88, 92])

# Calculate and print the average grade
average = student.average_grade()
print(f"{student.name}'s average grade: {average}")
# Out:
# LISHA's average grade: 91.25

# %%
#13) . Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the rea.

# %%
#13)  Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area.

class Rectangle:

    def __init__(self, length=0, width=0):

        self.length = length
        self.width = width

    def set_dimensions(self, length, width):

        self.length = length
        self.width = width

    def area(self):

        return self.length * self.width

# Create a Rectangle object
rectangle = Rectangle()

# Set the dimensions
rectangle.set_dimensions(5, 8)

# Calculate and print the area
area = rectangle.area()
print(f"Area of the rectangle: {area}")
# Out:
# Area of the rectangle: 40

# %%
#14)  Create a class Employee with a method calculate_salary() that computes the salary based on hours worked and hourly rate. Create a derived class Manager that adds a bonus to the salary.
class Employee:

    def __init__(self, name, hourly_rate):

        self.name = name
        self.hourly_rate = hourly_rate

    def calculate_salary(self, hours_worked):

        return hours_worked * self.hourly_rate


class Manager(Employee):

    def __init__(self, name, hourly_rate, bonus):

        super().__init__(name, hourly_rate)  # Call the parent class constructor
        self.bonus = bonus

    def calculate_salary(self, hours_worked):

        base_salary = super().calculate_salary(hours_worked)  # Call the parent class method
        return base_salary + self.bonus

# Create an Employee object
employee = Employee("LISHA", 300.0)

# Create a Manager object
manager = Manager("MEET", 30.0, 1000.0)

# Calculate and print salaries
employee_salary = employee.calculate_salary(40)
manager_salary = manager.calculate_salary(40)

print(f"{employee.name}'s salary: ${employee_salary:.2f}")
print(f"{manager.name}'s salary: ${manager_salary:.2f}")
# Out:
# LISHA's salary: $12000.00
# MEET's salary: $2200.00

# %%
#15)  Create a class Product with attributes name, price, and quantity. Implement a method total_price() that calculates the total price of the product.
class Product:

    def __init__(self, name, price, quantity):

        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):

        return self.price * self.quantity

# Create a Product object
product = Product("PHONE", 20000.00, 2)

# Calculate and print the total price
total = product.total_price()
print(f"Total price of {product.name}: INR {total:.2f}")
# Out:
# Total price of PHONE: INR 40000.00

# %%
#16)  Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that implement the sound() method.
from abc import ABC, abstractmethod

class Animal(ABC):

    @abstractmethod
    def sound(self):

        pass


class Cow(Animal):

    def sound(self):

        print("MOO")


class Sheep(Animal):

    def sound(self):

        print("BAA")


# Create instances of the classes
cow = Cow()
sheep = Sheep()

# Make the animals make their sounds
cow.sound()
sheep.sound()
# Out:
# MOO
# BAA

# %%
#17)Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that returns a formatted string with the book's details.
class Book:

    def __init__(self, title, author, year_published):

        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):

        return f"Title: {self.title}\nAuthor: {self.author}\nYear Published: {self.year_published}"

# Create a Book object
book = Book("TWO STATES", "Chetan bhagar", 2018)

# Get and print the book's information
book_info = book.get_book_info()
print(book_info)
# Out:
# Title: TWO STATES
# Author: Chetan bhagar
# Year Published: 2018

# %%
#18) Create a class House with attributes address and price. Create a derived class Mansion that adds an attribute number_of_rooms.
class House:

    def __init__(self, address, price):

        self.address = address
        self.price = price


class Mansion(House):

    def __init__(self, address, price, number_of_rooms):

        super().__init__(address, price)  # Call the parent class constructor
        self.number_of_rooms = number_of_rooms

# Create a House object
house = House("shivaji nagar", 5000000.00)

# Create a Mansion object
mansion = Mansion("sahakar nagar", 45000000.00, 8)

# Print some information
print(f"House address: {house.address}, Price: INR{house.price:.2f}")
print(f"Mansion address: {mansion.address}, Price: INR{mansion.price:.2f}, Rooms: {mansion.number_of_rooms}")
# Out:
# House address: shivaji nagar, Price: INR5000000.00
# Mansion address: sahakar nagar, Price: INR45000000.00, Rooms: 8
